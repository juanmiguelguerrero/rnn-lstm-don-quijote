# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, we'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('don-quijote.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# '\n\nPrimera parte del ingenioso hidalgo don Quijote de la Mancha\n\n\n\n\n\nCapítulo primero. Que trata de l'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([ 0,  0, 35, 63, 55, 58, 51, 63, 47,  1, 61, 47, 63, 65, 51,  1, 50,
#        51, 57,  1, 55, 59, 53, 51, 59, 55, 60, 64, 60,  1, 54, 55, 50, 47,
#        57, 53, 60,  1, 50, 60, 59,  1, 36, 66, 55, 56, 60, 65, 51,  1, 50,
#        51,  1, 57, 47,  1, 32, 47, 59, 49, 54, 47,  0,  0,  0,  0,  0,  0,
#        23, 47, 61, 83, 65, 66, 57, 60,  1, 61, 63, 55, 58, 51, 63, 60,  9,
#         1, 36, 66, 51,  1, 65, 63, 47, 65, 47,  1, 50, 51,  1, 57], dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 90

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
# We have our text encoded as integers as one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the number of batches we can make from some array `arr`, you divide the length of `arr` by the batch size. Once you know the number of batches and the batch size, you can get the total number of characters to keep.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`n_seqs` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$ where $K$ is the number of batches.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. You'll usually see the first input character used as the last target character, so something like this:
# ```python
# y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
# ```
# where `x` is the input batch and `y` is the target batch.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **Exercise:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = n_seqs * n_steps
    n_batches = len(arr)//characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:characters_per_batch * n_batches]
    
    # Reshape into n_seqs rows
    arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n: n+n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[ 0  0 35 63 55 58 51 63 47  1]
#  [ 1 65 82 63 58 55 59 60 64  7]
#  [58 60  1 62 66 51 50 47 48 47]
#  [47 48 83 47  1 64 55 50 60  1]
#  [51 50 55 63 58 51  1 50 82 57]
#  [55 51 63 60 59  1 61 60 63  1]
#  [66 51  1 49 60 59  0 51 64 65]
#  [ 1 50 51  1 64 51 53 66 55 63]
#  [50 47 59 65 51  7  1 55 59 49]
#  [50 51 56 47 59 50 60  1 47  1]]
#
# y
#  [[ 0 35 63 55 58 51 63 47  1 61]
#  [65 82 63 58 55 59 60 64  7  1]
#  [60  1 62 66 51 50 47 48 47  1]
#  [48 83 47  1 64 55 50 60  1 55]
#  [50 55 63 58 51  1 50 82 57  7]
#  [51 63 60 59  1 61 60 63  1 64]
#  [51  1 49 60 59  0 51 64 65 47]
#  [50 51  1 64 51 53 66 55 63 57]
#  [47 59 65 51  7  1 55 59 49 57]
#  [51 56 47 59 50 60  1 47  1 64]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`. This will be a scalar, that is a 0-D tensor. To make a scalar, you create a placeholder without giving it a size.
#
# > **Exercise:** Create the input placeholders in the function below.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, shape=(batch_size, num_steps), name="input")
    targets = tf.placeholder(tf.int32, shape=(batch_size, num_steps), name="targets")
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    # Use a basic LSTM cell
    # lstm = 
    
    # Add dropout to the cell outputs
    # drop = 
    
    # Stack up multiple LSTM layers, for deep learning

    def build_cell(num_units, keep_prob):
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

        return drop

    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character, so we want this layer to have size $C$, the number of classes/characters we have in our text.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells. We get the LSTM output as a list, `lstm_output`. First we need to concatenate this whole list into one array with [`tf.concat`](https://www.tensorflow.org/api_docs/python/tf/concat). Then, reshape it (with `tf.reshape`) to size $(M * N) \times L$.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.
#
# > **Exercise:** Implement the output layer in the function below.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # Concatenate lstm_output over axis 1 (the columns)
    seq_output = tf.concat(lstm_output, axis=1)
    # Reshape seq_output to a 2D tensor with lstm_size columns
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        # Create the weight and bias variables here
        softmax_w = tf.Variable(tf.truncated_normal([in_size, out_size], stddev=0.1))
        softmax_b = tf.Variable(tf.zeros([out_size]))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.add(tf.matmul(x, softmax_w), softmax_b)
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name="prediction")
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.
#
# >**Exercise:** Implement the loss calculation in the function below.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per sequence per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.
#
# > **Exercise:** Use the functions you've implemented previously and `tf.nn.dynamic_rnn` to build the network.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN with tf.nn.dynamic_rnn 
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 100        # Sequences per batch
num_steps = 100         # Number of sequence steps per batch
lstm_size = 512         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.001   # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`
#
# > **Exercise:** Set the hyperparameters above to train the network. Watch the training loss, it should be consistently dropping. Also, I highly advise running this on a GPU.

# %%
epochs = 20
# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            
            end = time.time()
            print('Epoch: {}/{}... '.format(e+1, epochs),
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 1...  Training loss: 4.4991...  6.3301 sec/batch
# Epoch: 1/20...  Training Step: 2...  Training loss: 4.3982...  6.2324 sec/batch
# Epoch: 1/20...  Training Step: 3...  Training loss: 3.8244...  6.2283 sec/batch
# Epoch: 1/20...  Training Step: 4...  Training loss: 5.0819...  6.2664 sec/batch
# Epoch: 1/20...  Training Step: 5...  Training loss: 4.3866...  6.2201 sec/batch
# Epoch: 1/20...  Training Step: 6...  Training loss: 3.9643...  6.2197 sec/batch
# Epoch: 1/20...  Training Step: 7...  Training loss: 3.6788...  6.2932 sec/batch
# Epoch: 1/20...  Training Step: 8...  Training loss: 3.5896...  6.2119 sec/batch
# Epoch: 1/20...  Training Step: 9...  Training loss: 3.4702...  6.2434 sec/batch
# Epoch: 1/20...  Training Step: 10...  Training loss: 3.4087...  6.2237 sec/batch
# Epoch: 1/20...  Training Step: 11...  Training loss: 3.3571...  6.2172 sec/batch
# Epoch: 1/20...  Training Step: 12...  Training loss: 3.3022...  6.2380 sec/batch
# Epoch: 1/20...  Training Step: 13...  Training loss: 3.3137...  6.2671 sec/batch
# Epoch: 1/20...  Training Step: 14...  Training loss: 3.2962...  6.2618 sec/batch
# Epoch: 1/20...  Training Step: 15...  Training loss: 3.2775...  6.3107 sec/batch
# Epoch: 1/20...  Training Step: 16...  Training loss: 3.2798...  6.2962 sec/batch
# Epoch: 1/20...  Training Step: 17...  Training loss: 3.2535...  6.1604 sec/batch
# Epoch: 1/20...  Training Step: 18...  Training loss: 3.2311...  6.2992 sec/batch
# Epoch: 1/20...  Training Step: 19...  Training loss: 3.2545...  6.2343 sec/batch
# Epoch: 1/20...  Training Step: 20...  Training loss: 3.2266...  6.2283 sec/batch
# Epoch: 1/20...  Training Step: 21...  Training loss: 3.2052...  6.2406 sec/batch
# Epoch: 1/20...  Training Step: 22...  Training loss: 3.2171...  6.2569 sec/batch
# Epoch: 1/20...  Training Step: 23...  Training loss: 3.1846...  6.1939 sec/batch
# Epoch: 1/20...  Training Step: 24...  Training loss: 3.2070...  6.2309 sec/batch
# Epoch: 1/20...  Training Step: 25...  Training loss: 3.1856...  6.2224 sec/batch
# Epoch: 1/20...  Training Step: 26...  Training loss: 3.1845...  6.2942 sec/batch
# Epoch: 1/20...  Training Step: 27...  Training loss: 3.1657...  6.2704 sec/batch
# Epoch: 1/20...  Training Step: 28...  Training loss: 3.1395...  6.2514 sec/batch
# Epoch: 1/20...  Training Step: 29...  Training loss: 3.1541...  6.2768 sec/batch
# Epoch: 1/20...  Training Step: 30...  Training loss: 3.1443...  6.3135 sec/batch
# Epoch: 1/20...  Training Step: 31...  Training loss: 3.1317...  6.1965 sec/batch
# Epoch: 1/20...  Training Step: 32...  Training loss: 3.1528...  6.1799 sec/batch
# Epoch: 1/20...  Training Step: 33...  Training loss: 3.1402...  6.2852 sec/batch
# Epoch: 1/20...  Training Step: 34...  Training loss: 3.1486...  6.2634 sec/batch
# Epoch: 1/20...  Training Step: 35...  Training loss: 3.1439...  6.2703 sec/batch
# Epoch: 1/20...  Training Step: 36...  Training loss: 3.1033...  6.2251 sec/batch
# Epoch: 1/20...  Training Step: 37...  Training loss: 3.1160...  6.2344 sec/batch
# Epoch: 1/20...  Training Step: 38...  Training loss: 3.1208...  6.2645 sec/batch
# Epoch: 1/20...  Training Step: 39...  Training loss: 3.1410...  6.2075 sec/batch
# Epoch: 1/20...  Training Step: 40...  Training loss: 3.1200...  6.2309 sec/batch
# Epoch: 1/20...  Training Step: 41...  Training loss: 3.1449...  6.2189 sec/batch
# Epoch: 1/20...  Training Step: 42...  Training loss: 3.1066...  6.3020 sec/batch
# Epoch: 1/20...  Training Step: 43...  Training loss: 3.1183...  6.3134 sec/batch
# Epoch: 1/20...  Training Step: 44...  Training loss: 3.1491...  6.3017 sec/batch
# Epoch: 1/20...  Training Step: 45...  Training loss: 3.1241...  6.2608 sec/batch
# Epoch: 1/20...  Training Step: 46...  Training loss: 3.1111...  6.2112 sec/batch
# Epoch: 1/20...  Training Step: 47...  Training loss: 3.0892...  6.2554 sec/batch
# Epoch: 1/20...  Training Step: 48...  Training loss: 3.1079...  6.2476 sec/batch
# Epoch: 1/20...  Training Step: 49...  Training loss: 3.1145...  6.2049 sec/batch
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1044...  6.1868 sec/batch
# Epoch: 1/20...  Training Step: 51...  Training loss: 3.1097...  6.2760 sec/batch
# Epoch: 1/20...  Training Step: 52...  Training loss: 3.1001...  6.2329 sec/batch
# Epoch: 1/20...  Training Step: 53...  Training loss: 3.0949...  6.2524 sec/batch
# Epoch: 1/20...  Training Step: 54...  Training loss: 3.0916...  6.2657 sec/batch
# Epoch: 1/20...  Training Step: 55...  Training loss: 3.0998...  6.2845 sec/batch
# Epoch: 1/20...  Training Step: 56...  Training loss: 3.0939...  6.2822 sec/batch
# Epoch: 1/20...  Training Step: 57...  Training loss: 3.0542...  6.2772 sec/batch
# Epoch: 1/20...  Training Step: 58...  Training loss: 3.1021...  6.2263 sec/batch
# Epoch: 1/20...  Training Step: 59...  Training loss: 3.0916...  6.2589 sec/batch
# Epoch: 1/20...  Training Step: 60...  Training loss: 3.1002...  6.2568 sec/batch
# Epoch: 1/20...  Training Step: 61...  Training loss: 3.0777...  6.2303 sec/batch
# Epoch: 1/20...  Training Step: 62...  Training loss: 3.0939...  6.2257 sec/batch
# Epoch: 1/20...  Training Step: 63...  Training loss: 3.0873...  6.2326 sec/batch
# Epoch: 1/20...  Training Step: 64...  Training loss: 3.0658...  6.1863 sec/batch
# Epoch: 1/20...  Training Step: 65...  Training loss: 3.0678...  6.1953 sec/batch
# Epoch: 1/20...  Training Step: 66...  Training loss: 3.0880...  6.2507 sec/batch
# Epoch: 1/20...  Training Step: 67...  Training loss: 3.0766...  6.2594 sec/batch
# Epoch: 1/20...  Training Step: 68...  Training loss: 3.0897...  6.2319 sec/batch
# Epoch: 1/20...  Training Step: 69...  Training loss: 3.1023...  6.2852 sec/batch
# Epoch: 1/20...  Training Step: 70...  Training loss: 3.0820...  6.3156 sec/batch
# Epoch: 1/20...  Training Step: 71...  Training loss: 3.0741...  6.2741 sec/batch
# Epoch: 1/20...  Training Step: 72...  Training loss: 3.0920...  6.2636 sec/batch
# Epoch: 1/20...  Training Step: 73...  Training loss: 3.0718...  6.2710 sec/batch
# Epoch: 1/20...  Training Step: 74...  Training loss: 3.0765...  6.1979 sec/batch
# Epoch: 1/20...  Training Step: 75...  Training loss: 3.0627...  6.2287 sec/batch
# Epoch: 1/20...  Training Step: 76...  Training loss: 3.0533...  6.2442 sec/batch
# Epoch: 1/20...  Training Step: 77...  Training loss: 3.0683...  6.2029 sec/batch
# Epoch: 1/20...  Training Step: 78...  Training loss: 3.0651...  6.2213 sec/batch
# Epoch: 1/20...  Training Step: 79...  Training loss: 3.0690...  6.2124 sec/batch
# Epoch: 1/20...  Training Step: 80...  Training loss: 3.0566...  6.2246 sec/batch
# Epoch: 1/20...  Training Step: 81...  Training loss: 3.0511...  6.1786 sec/batch
# Epoch: 1/20...  Training Step: 82...  Training loss: 3.0528...  6.2573 sec/batch
# Epoch: 1/20...  Training Step: 83...  Training loss: 3.0542...  6.2290 sec/batch
# Epoch: 1/20...  Training Step: 84...  Training loss: 3.0576...  6.2063 sec/batch
# Epoch: 1/20...  Training Step: 85...  Training loss: 3.0559...  6.3137 sec/batch
# Epoch: 1/20...  Training Step: 86...  Training loss: 3.0563...  6.2462 sec/batch
# Epoch: 1/20...  Training Step: 87...  Training loss: 3.0281...  6.2240 sec/batch
# Epoch: 1/20...  Training Step: 88...  Training loss: 3.0546...  6.2666 sec/batch
# Epoch: 1/20...  Training Step: 89...  Training loss: 3.0434...  6.2131 sec/batch
# Epoch: 1/20...  Training Step: 90...  Training loss: 3.0530...  6.2350 sec/batch
# Epoch: 1/20...  Training Step: 91...  Training loss: 3.0352...  6.1918 sec/batch
# Epoch: 1/20...  Training Step: 92...  Training loss: 3.0734...  6.2490 sec/batch
# Epoch: 1/20...  Training Step: 93...  Training loss: 3.0307...  6.2095 sec/batch
# Epoch: 1/20...  Training Step: 94...  Training loss: 3.0814...  6.2605 sec/batch
# Epoch: 1/20...  Training Step: 95...  Training loss: 3.0448...  6.2684 sec/batch
# Epoch: 1/20...  Training Step: 96...  Training loss: 3.0706...  6.2449 sec/batch
# Epoch: 1/20...  Training Step: 97...  Training loss: 3.0540...  6.2455 sec/batch
# Epoch: 1/20...  Training Step: 98...  Training loss: 3.0387...  6.2295 sec/batch
# Epoch: 1/20...  Training Step: 99...  Training loss: 3.0469...  6.2339 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 3.0563...  6.2833 sec/batch
# Epoch: 1/20...  Training Step: 101...  Training loss: 3.0402...  6.2290 sec/batch
# Epoch: 1/20...  Training Step: 102...  Training loss: 3.0298...  6.2682 sec/batch
# Epoch: 1/20...  Training Step: 103...  Training loss: 3.0390...  6.2663 sec/batch
# Epoch: 1/20...  Training Step: 104...  Training loss: 3.0576...  6.2491 sec/batch
# Epoch: 1/20...  Training Step: 105...  Training loss: 3.0301...  6.2142 sec/batch
# Epoch: 1/20...  Training Step: 106...  Training loss: 3.0228...  6.2536 sec/batch
# Epoch: 1/20...  Training Step: 107...  Training loss: 3.0307...  6.2269 sec/batch
# Epoch: 1/20...  Training Step: 108...  Training loss: 3.0372...  6.2063 sec/batch
# Epoch: 1/20...  Training Step: 109...  Training loss: 3.0040...  6.1719 sec/batch
# Epoch: 1/20...  Training Step: 110...  Training loss: 3.0023...  6.2498 sec/batch
# Epoch: 1/20...  Training Step: 111...  Training loss: 3.0080...  6.2270 sec/batch
# Epoch: 1/20...  Training Step: 112...  Training loss: 3.0277...  6.2081 sec/batch
# Epoch: 1/20...  Training Step: 113...  Training loss: 3.0132...  6.2691 sec/batch
# Epoch: 1/20...  Training Step: 114...  Training loss: 2.9961...  6.2618 sec/batch
# Epoch: 1/20...  Training Step: 115...  Training loss: 2.9975...  6.2491 sec/batch
# Epoch: 1/20...  Training Step: 116...  Training loss: 2.9867...  6.2376 sec/batch
# Epoch: 1/20...  Training Step: 117...  Training loss: 3.0077...  6.2875 sec/batch
# Epoch: 1/20...  Training Step: 118...  Training loss: 2.9758...  6.2383 sec/batch
# Epoch: 1/20...  Training Step: 119...  Training loss: 2.9742...  6.2293 sec/batch
# Epoch: 1/20...  Training Step: 120...  Training loss: 2.9788...  6.3014 sec/batch
# Epoch: 1/20...  Training Step: 121...  Training loss: 2.9991...  6.1959 sec/batch
# Epoch: 1/20...  Training Step: 122...  Training loss: 2.9729...  6.2132 sec/batch
# Epoch: 1/20...  Training Step: 123...  Training loss: 2.9723...  6.2239 sec/batch
# Epoch: 1/20...  Training Step: 124...  Training loss: 2.9640...  6.2711 sec/batch
# Epoch: 1/20...  Training Step: 125...  Training loss: 2.9560...  6.2309 sec/batch
# Epoch: 1/20...  Training Step: 126...  Training loss: 3.0354...  6.2049 sec/batch
# Epoch: 1/20...  Training Step: 127...  Training loss: 3.0116...  6.2487 sec/batch
# Epoch: 1/20...  Training Step: 128...  Training loss: 3.0087...  6.3032 sec/batch
# Epoch: 1/20...  Training Step: 129...  Training loss: 2.9746...  6.2282 sec/batch
# Epoch: 1/20...  Training Step: 130...  Training loss: 2.9567...  6.2574 sec/batch
# Epoch: 1/20...  Training Step: 131...  Training loss: 2.9750...  6.3097 sec/batch
# Epoch: 1/20...  Training Step: 132...  Training loss: 2.9943...  6.2803 sec/batch
# Epoch: 1/20...  Training Step: 133...  Training loss: 2.9582...  6.2305 sec/batch
# Epoch: 1/20...  Training Step: 134...  Training loss: 2.9498...  6.2087 sec/batch
# Epoch: 1/20...  Training Step: 135...  Training loss: 2.9553...  6.1907 sec/batch
# Epoch: 1/20...  Training Step: 136...  Training loss: 2.9145...  6.2576 sec/batch
# Epoch: 1/20...  Training Step: 137...  Training loss: 2.9358...  6.2412 sec/batch
# Epoch: 1/20...  Training Step: 138...  Training loss: 2.9251...  6.2079 sec/batch
# Epoch: 1/20...  Training Step: 139...  Training loss: 2.9460...  6.2030 sec/batch
# Epoch: 1/20...  Training Step: 140...  Training loss: 2.9053...  6.2960 sec/batch
# Epoch: 1/20...  Training Step: 141...  Training loss: 2.9162...  6.2290 sec/batch
# Epoch: 1/20...  Training Step: 142...  Training loss: 2.9083...  6.2931 sec/batch
# Epoch: 1/20...  Training Step: 143...  Training loss: 2.8761...  6.2548 sec/batch
# Epoch: 1/20...  Training Step: 144...  Training loss: 2.8777...  6.2460 sec/batch
# Epoch: 1/20...  Training Step: 145...  Training loss: 2.8875...  6.2544 sec/batch
# Epoch: 1/20...  Training Step: 146...  Training loss: 2.8880...  6.2320 sec/batch
# Epoch: 1/20...  Training Step: 147...  Training loss: 2.8803...  6.2624 sec/batch
# Epoch: 1/20...  Training Step: 148...  Training loss: 2.8420...  6.2690 sec/batch
# Epoch: 1/20...  Training Step: 149...  Training loss: 2.8466...  6.2515 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.8245...  6.2255 sec/batch
# Epoch: 1/20...  Training Step: 151...  Training loss: 2.8341...  6.2314 sec/batch
# Epoch: 1/20...  Training Step: 152...  Training loss: 2.7862...  6.2203 sec/batch
# Epoch: 1/20...  Training Step: 153...  Training loss: 2.7921...  6.2529 sec/batch
# Epoch: 1/20...  Training Step: 154...  Training loss: 2.7806...  6.3027 sec/batch
# Epoch: 1/20...  Training Step: 155...  Training loss: 2.7813...  6.2063 sec/batch
# Epoch: 1/20...  Training Step: 156...  Training loss: 2.7828...  6.2280 sec/batch
# Epoch: 1/20...  Training Step: 157...  Training loss: 2.7823...  6.2544 sec/batch
# Epoch: 1/20...  Training Step: 158...  Training loss: 2.7664...  6.2489 sec/batch
# Epoch: 1/20...  Training Step: 159...  Training loss: 2.7577...  6.2914 sec/batch
# Epoch: 1/20...  Training Step: 160...  Training loss: 2.7438...  6.3056 sec/batch
# Epoch: 1/20...  Training Step: 161...  Training loss: 2.7187...  6.2728 sec/batch
# Epoch: 1/20...  Training Step: 162...  Training loss: 2.7975...  6.2046 sec/batch
# Epoch: 1/20...  Training Step: 163...  Training loss: 2.7727...  6.2119 sec/batch
# Epoch: 1/20...  Training Step: 164...  Training loss: 2.8058...  6.2794 sec/batch
# Epoch: 1/20...  Training Step: 165...  Training loss: 2.7702...  6.2524 sec/batch
# Epoch: 1/20...  Training Step: 166...  Training loss: 2.7563...  6.2061 sec/batch
# Epoch: 1/20...  Training Step: 167...  Training loss: 2.7407...  6.2487 sec/batch
# Epoch: 1/20...  Training Step: 168...  Training loss: 2.7064...  6.2185 sec/batch
# Epoch: 1/20...  Training Step: 169...  Training loss: 2.7033...  6.2547 sec/batch
# Epoch: 1/20...  Training Step: 170...  Training loss: 2.7091...  6.2549 sec/batch
# Epoch: 1/20...  Training Step: 171...  Training loss: 2.6841...  6.2527 sec/batch
# Epoch: 1/20...  Training Step: 172...  Training loss: 2.6918...  6.2429 sec/batch
# Epoch: 1/20...  Training Step: 173...  Training loss: 2.6589...  6.2355 sec/batch
# Epoch: 1/20...  Training Step: 174...  Training loss: 2.6763...  6.2797 sec/batch
# Epoch: 1/20...  Training Step: 175...  Training loss: 2.6604...  6.2426 sec/batch
# Epoch: 1/20...  Training Step: 176...  Training loss: 2.6437...  6.3103 sec/batch
# Epoch: 1/20...  Training Step: 177...  Training loss: 2.6263...  6.2243 sec/batch
# Epoch: 1/20...  Training Step: 178...  Training loss: 2.6357...  6.2234 sec/batch
# Epoch: 1/20...  Training Step: 179...  Training loss: 2.7207...  6.2662 sec/batch
# Epoch: 1/20...  Training Step: 180...  Training loss: 2.5932...  6.1948 sec/batch
# Epoch: 1/20...  Training Step: 181...  Training loss: 2.5796...  6.2012 sec/batch
# Epoch: 1/20...  Training Step: 182...  Training loss: 2.5930...  6.1742 sec/batch
# Epoch: 1/20...  Training Step: 183...  Training loss: 2.6000...  6.2506 sec/batch
# Epoch: 1/20...  Training Step: 184...  Training loss: 2.5787...  6.1987 sec/batch
# Epoch: 1/20...  Training Step: 185...  Training loss: 2.5902...  6.2497 sec/batch
# Epoch: 1/20...  Training Step: 186...  Training loss: 2.5823...  6.1940 sec/batch
# Epoch: 1/20...  Training Step: 187...  Training loss: 2.5953...  6.2565 sec/batch
# Epoch: 1/20...  Training Step: 188...  Training loss: 2.5710...  6.2731 sec/batch
# Epoch: 1/20...  Training Step: 189...  Training loss: 2.5502...  6.2240 sec/batch
# Epoch: 1/20...  Training Step: 190...  Training loss: 2.5581...  6.2728 sec/batch
# Epoch: 1/20...  Training Step: 191...  Training loss: 2.5290...  6.2857 sec/batch
# Epoch: 1/20...  Training Step: 192...  Training loss: 2.5202...  6.1858 sec/batch
# Epoch: 1/20...  Training Step: 193...  Training loss: 2.5284...  6.2106 sec/batch
# Epoch: 1/20...  Training Step: 194...  Training loss: 2.5022...  6.2118 sec/batch
# Epoch: 1/20...  Training Step: 195...  Training loss: 2.5104...  6.2534 sec/batch
# Epoch: 1/20...  Training Step: 196...  Training loss: 2.5071...  6.2499 sec/batch
# Epoch: 1/20...  Training Step: 197...  Training loss: 2.5167...  6.2567 sec/batch
# Epoch: 1/20...  Training Step: 198...  Training loss: 2.5209...  6.2459 sec/batch
# Epoch: 1/20...  Training Step: 199...  Training loss: 2.4984...  6.2064 sec/batch
# Epoch: 1/20...  Training Step: 200...  Training loss: 2.4923...  6.2278 sec/batch
# Epoch: 1/20...  Training Step: 201...  Training loss: 2.4906...  6.2296 sec/batch
# Epoch: 1/20...  Training Step: 202...  Training loss: 2.4717...  6.3131 sec/batch
# Epoch: 1/20...  Training Step: 203...  Training loss: 2.4825...  6.2185 sec/batch
# Epoch: 1/20...  Training Step: 204...  Training loss: 2.4559...  6.2924 sec/batch
# Epoch: 1/20...  Training Step: 205...  Training loss: 2.4437...  6.2902 sec/batch
# Epoch: 1/20...  Training Step: 206...  Training loss: 2.4692...  6.2665 sec/batch
# Epoch: 1/20...  Training Step: 207...  Training loss: 2.4456...  6.2027 sec/batch
# Epoch: 2/20...  Training Step: 208...  Training loss: 2.4912...  6.2332 sec/batch
# Epoch: 2/20...  Training Step: 209...  Training loss: 2.4312...  6.2543 sec/batch
# Epoch: 2/20...  Training Step: 210...  Training loss: 2.4528...  6.2692 sec/batch
# Epoch: 2/20...  Training Step: 211...  Training loss: 2.4575...  6.1777 sec/batch
# Epoch: 2/20...  Training Step: 212...  Training loss: 2.4163...  6.2847 sec/batch
# Epoch: 2/20...  Training Step: 213...  Training loss: 2.4238...  6.2231 sec/batch
# Epoch: 2/20...  Training Step: 214...  Training loss: 2.4039...  6.2314 sec/batch
# Epoch: 2/20...  Training Step: 215...  Training loss: 2.4120...  6.2356 sec/batch
# Epoch: 2/20...  Training Step: 216...  Training loss: 2.3855...  6.2332 sec/batch
# Epoch: 2/20...  Training Step: 217...  Training loss: 2.3958...  6.2768 sec/batch
# Epoch: 2/20...  Training Step: 218...  Training loss: 2.3943...  6.2717 sec/batch
# Epoch: 2/20...  Training Step: 219...  Training loss: 2.3660...  6.2455 sec/batch
# Epoch: 2/20...  Training Step: 220...  Training loss: 2.3913...  6.2467 sec/batch
# Epoch: 2/20...  Training Step: 221...  Training loss: 2.3730...  6.2034 sec/batch
# Epoch: 2/20...  Training Step: 222...  Training loss: 2.3512...  6.2488 sec/batch
# Epoch: 2/20...  Training Step: 223...  Training loss: 2.3826...  6.2099 sec/batch
# Epoch: 2/20...  Training Step: 224...  Training loss: 2.3618...  6.2288 sec/batch
# Epoch: 2/20...  Training Step: 225...  Training loss: 2.3617...  6.1947 sec/batch
# Epoch: 2/20...  Training Step: 226...  Training loss: 2.4169...  6.1984 sec/batch
# Epoch: 3/20...  Training Step: 576...  Training loss: 1.9066...  6.2770 sec/batch
# Epoch: 3/20...  Training Step: 577...  Training loss: 1.9202...  6.2522 sec/batch
# Epoch: 3/20...  Training Step: 578...  Training loss: 1.9643...  6.2976 sec/batch
# Epoch: 3/20...  Training Step: 579...  Training loss: 1.9752...  6.2368 sec/batch
# Epoch: 3/20...  Training Step: 580...  Training loss: 1.9358...  6.2550 sec/batch
# Epoch: 3/20...  Training Step: 581...  Training loss: 1.9566...  6.3119 sec/batch
# Epoch: 3/20...  Training Step: 582...  Training loss: 1.9227...  6.2259 sec/batch
# Epoch: 3/20...  Training Step: 583...  Training loss: 1.9378...  6.2567 sec/batch
# Epoch: 3/20...  Training Step: 584...  Training loss: 1.9494...  6.2622 sec/batch
# Epoch: 3/20...  Training Step: 585...  Training loss: 1.9583...  6.2402 sec/batch
# Epoch: 3/20...  Training Step: 586...  Training loss: 1.9740...  6.2984 sec/batch
# ...
# Epoch: 20/20...  Training Step: 3951...  Training loss: 1.2855...  6.3643 sec/batch
# Epoch: 20/20...  Training Step: 3952...  Training loss: 1.2971...  6.2808 sec/batch
# Epoch: 20/20...  Training Step: 3953...  Training loss: 1.2740...  6.2662 sec/batch
# Epoch: 20/20...  Training Step: 3954...  Training loss: 1.2827...  6.2874 sec/batch
# Epoch: 20/20...  Training Step: 3955...  Training loss: 1.2726...  6.1960 sec/batch
# Epoch: 20/20...  Training Step: 3956...  Training loss: 1.2731...  6.2220 sec/batch
# Epoch: 20/20...  Training Step: 3957...  Training loss: 1.2664...  6.1878 sec/batch
# Epoch: 20/20...  Training Step: 3958...  Training loss: 1.2726...  6.2356 sec/batch
# Epoch: 20/20...  Training Step: 3959...  Training loss: 1.3004...  6.2360 sec/batch
# Epoch: 20/20...  Training Step: 3960...  Training loss: 1.2815...  6.3008 sec/batch
# Epoch: 20/20...  Training Step: 3961...  Training loss: 1.2767...  6.2069 sec/batch
# Epoch: 20/20...  Training Step: 3962...  Training loss: 1.2683...  6.2256 sec/batch
# Epoch: 20/20...  Training Step: 3963...  Training loss: 1.2798...  6.2189 sec/batch
# Epoch: 20/20...  Training Step: 3964...  Training loss: 1.2556...  6.2312 sec/batch
# Epoch: 20/20...  Training Step: 3965...  Training loss: 1.2731...  6.2547 sec/batch
# Epoch: 20/20...  Training Step: 3966...  Training loss: 1.3059...  6.2931 sec/batch
# Epoch: 20/20...  Training Step: 3967...  Training loss: 1.2946...  6.2657 sec/batch
# Epoch: 20/20...  Training Step: 3968...  Training loss: 1.2991...  6.2323 sec/batch
# Epoch: 20/20...  Training Step: 3969...  Training loss: 1.2672...  6.2118 sec/batch
# Epoch: 20/20...  Training Step: 3970...  Training loss: 1.2855...  6.2712 sec/batch
# Epoch: 20/20...  Training Step: 3971...  Training loss: 1.2700...  6.2677 sec/batch
# Epoch: 20/20...  Training Step: 3972...  Training loss: 1.2685...  6.2585 sec/batch
# Epoch: 20/20...  Training Step: 3973...  Training loss: 1.2798...  6.2339 sec/batch
# Epoch: 20/20...  Training Step: 4111...  Training loss: 1.2444...  6.2690 sec/batch
# Epoch: 20/20...  Training Step: 4112...  Training loss: 1.3040...  6.2328 sec/batch
# Epoch: 20/20...  Training Step: 4113...  Training loss: 1.2735...  6.2301 sec/batch
# Epoch: 20/20...  Training Step: 4114...  Training loss: 1.2494...  6.2450 sec/batch
# Epoch: 20/20...  Training Step: 4115...  Training loss: 1.2721...  6.2177 sec/batch
# Epoch: 20/20...  Training Step: 4116...  Training loss: 1.2873...  6.2369 sec/batch
# Epoch: 20/20...  Training Step: 4117...  Training loss: 1.3064...  6.2567 sec/batch
# Epoch: 20/20...  Training Step: 4118...  Training loss: 1.2811...  6.2698 sec/batch
# Epoch: 20/20...  Training Step: 4119...  Training loss: 1.2710...  6.2766 sec/batch
# Epoch: 20/20...  Training Step: 4120...  Training loss: 1.2687...  6.2505 sec/batch
# Epoch: 20/20...  Training Step: 4121...  Training loss: 1.2626...  6.2519 sec/batch
# Epoch: 20/20...  Training Step: 4122...  Training loss: 1.2680...  6.2330 sec/batch
# Epoch: 20/20...  Training Step: 4123...  Training loss: 1.2975...  6.2383 sec/batch
# Epoch: 20/20...  Training Step: 4124...  Training loss: 1.2638...  6.2343 sec/batch
# Epoch: 20/20...  Training Step: 4125...  Training loss: 1.2780...  6.2582 sec/batch
# Epoch: 20/20...  Training Step: 4126...  Training loss: 1.2746...  6.2411 sec/batch
# Epoch: 20/20...  Training Step: 4127...  Training loss: 1.2823...  6.2232 sec/batch
# Epoch: 20/20...  Training Step: 4128...  Training loss: 1.2831...  6.2354 sec/batch
# Epoch: 20/20...  Training Step: 4129...  Training loss: 1.2618...  6.1937 sec/batch
# Epoch: 20/20...  Training Step: 4130...  Training loss: 1.3028...  6.2725 sec/batch
# Epoch: 20/20...  Training Step: 4131...  Training loss: 1.2609...  6.2637 sec/batch
# Epoch: 20/20...  Training Step: 4132...  Training loss: 1.2661...  6.2830 sec/batch
# Epoch: 20/20...  Training Step: 4133...  Training loss: 1.2644...  6.2827 sec/batch
# Epoch: 20/20...  Training Step: 4134...  Training loss: 1.3097...  6.3292 sec/batch
# Epoch: 20/20...  Training Step: 4135...  Training loss: 1.2886...  6.2699 sec/batch
# Epoch: 20/20...  Training Step: 4136...  Training loss: 1.2446...  6.2548 sec/batch
# Epoch: 20/20...  Training Step: 4137...  Training loss: 1.2751...  6.2327 sec/batch
# Epoch: 20/20...  Training Step: 4138...  Training loss: 1.2973...  6.2547 sec/batch
# Epoch: 20/20...  Training Step: 4139...  Training loss: 1.2835...  6.2073 sec/batch
# Epoch: 20/20...  Training Step: 4140...  Training loss: 1.2892...  6.2920 sec/batch

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i4140_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i1800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i2800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3200_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3400_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3600_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i3800_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i4000_l512.ckpt"
# all_model_checkpoint_paths: "checkpoints/i4140_l512.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i4140_l512.ckpt'

# %%
#checkpoint = tf.train.latest_checkpoint('checkpoints')
checkpoint = './i4140_l512.ckpt'
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Erase una vez ")
print(samp)
# Out:
# Erase una vez presencia que, al cual, con todo su
# esposo, y la padre de su cana, dijo a Sancho, que los que las parece suelen
# sigo escuderos de su carto, que, por más de su mesmo desaguisado, que el
# cual, con turbada y engerida, y llevaron a prueba en la mano, y luego la
# dejó de adornos, dejando con todo cuanto en este tengo, se lo dejaron
# alegres y su aldeana; y la cual, a quien er que de su poderosa empresó se
# despidió, por la menos, con tanta male y con el castillo, solase de
# mescado, cerrada y el camino de la causa, puesto de armado conocido a los
# más respondes de la soldada, de cómo al desencantador dice:
#
# -Si es de las cueles se ha dicho, que los mesmos que su pedaz, deje mi
# señor en los día y a mi marido este donarre que te llega el diablo, y
# sabes, y nunca se hay pramio, que le de más dormir a tantas pruebas donde se
# poco a su partida, sino a más consejo, que en eso si muerto en la cabezna
#    quiera saber que más me ha hacedo
#    que mi señor de la manera quedrás
# escudero, y que si no me acuerdo de mayores,o a lo que hace más, que
# es el mesmo pelo de la ventura; pero no tuviesen los dos, que
# tenerlos para estas reinas, cuando está alegre desta vida; que si no le
# han perdido mil suspiros, con los criados que le dejan a los dos cuantos le
# parecen, para qué me han de poca el cuento y por el mismo de mi amo y alguna,
# con ellos lo que se me dice por lo que se los tiene de alcanzar la merece,
# porque ser los cortes que se están a lingo de aquéllos y parecerlas en el
# moro en la venta, para que tan bien son mucho de su señor, y, como el
# son que me han de hacer algo entre el preguntamiento: de lo que me da mi
# primer contra el sol de ti marcel como el pregunto y cura y de lo que
# sus cosas quieren, que yo le de carta el pobre podrido hablan al mesmo prado;
# que yo hay por menos, como la historia que si mi malo de escosa, que le
# ha de pudo, sino el que todos los que son los compatas de condenados; que
# lo que déste mante mi el punto que se les parezcan en ella sin el deseo de
# los caballos

# %%
checkpoint = 'checkpoints/i200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Erase una vez ")
print(samp)
# Out:
# Erase una vez ara e la peres, al a las eros asten era as ar es ciro qes
# ala que pos direr di dus las es er a lara es e enca den do le dinas de en er uon en a en an ora qe elel rue a ale que pel ore an ar lasa es liro, que e curo que e mar es dusta,, que lon os en as lerar e con oro do
# to to de les a don al lirera el la lo lo que enande, ane pore lantos or ol era al lera an ua al eno des
# ensa den as eresa qele ane poste, peno der iastos e dun ar o lu en as an lo cia antana a de core las de den ol do ceno e lo postana el due den o e a eral ane que dintias os estia do dosss linos o la as lu due do col lo quu ertera, a lo an lus an en a la an a a as liana la des le an e alta certa a duen an altara diro la co as an ar o li or os ans en a le den a alos al o lar ios a la antros qee listan en eno ane er a en o lente lo pertera an a cirrastda, yre lo lontio an a la do el den de cor en li es an es er a contentias ero de las ane, a en la due dor larto di die do qee era ar ane an lela que pira de larardo que est

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Erase una vez ")
print(samp)
# Out:
# Erase una vez encentar suerte y
# escadado a su acasión. Y su suy a mis razonade y contiriosa de la cosa, señora don Quijote; de lo que está en todo
# la de manas y menos que se lendo del de
# lo que hasta en el minotro crayo de la mano de su pociento y en manos a
# la vilerte, y allí se acortó, y, al de señora el mano don
# Quijote, y allí con la puede de molera a la paltura y a las anchas padas, porque, si aquela para mucho
# dejarte espero en todo el menorme, se hombre de con todo los pundo de cabliller,
# camina al minos de caballero, allín, y, a qué dijo a lugeros que en las andanas y
# antreseguintimas; pero al cartallos, y a la mil de la porta contendad que le panera que no hoyo don Quijote que emos, y
# espadar lo que diese en el mano, y así
# en malando de su partencia de lo que a lo mendo a
# la
# dura de la cual su dieren, que si mis de la carrando; y, alguna de las provechas por mi mucha conazón a su pacio.
#
# -¡Es más muy bien ados, porque le amigo a su suñado de las amoses que el cuerpo.
#
# En la panta, que es los

# %%
checkpoint = 'checkpoints/i3400_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Erase una vez ")
print(samp)
# Out:
# Erase una vez suerte, y
# así le dijeron que salía cristianos y acomodadas a cuantas la verdad
# suele ella en las corazos, y dijirlo que a las cosas que se acabana de su
# caballo y dos costrades castillos, con las calles; y que aquel cosas que
# he puesto esta andante caballería, que si no hace en todos en el camino
# palabra, para que le preguntarán diciendo que la doncella en su señor deseos
# de lociras, que, sin hallarse, que siendo la pena de mi padre y el siempre de
# lo que lo dijesen que su señor había de decir, y daba con la mano, diciendo
# que aquí al dicho que sucedió don Quijote de la concertada duquesa, porque
# no le parece que estaba para que el precio de mi amo la contó a su armita que
# su caballo se las dijo:
#
# -Seguían lo que se descubrieren a la cabeza, que en la carta que luego allí
# leer a mi puerta a ser amante con ellas.
#
# »Era comedida, y estos conocidos y el del día, y el parro del sueño de
# los caballeros, y el pastor, don Gelesillo; y, así como a su puerto en ellas
# a sus caballesos, porque tod
